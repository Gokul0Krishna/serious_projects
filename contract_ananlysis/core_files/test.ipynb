# %%
import pymupdf

# %%
doc = pymupdf.open(r'C:\Users\ASUS\OneDrive\Desktop\code\serious_projects\contract_ananlysis\support_docs\petn4-781-exhibits.pdf')

# %%
doc.load_page(1)
# Out:
# page 1 of C:\Users\ASUS\OneDrive\Desktop\code\serious_projects\contract_ananlysis\support_docs\petn4-781-exhibits.pdf
