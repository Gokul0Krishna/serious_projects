# %%
import json
import pandas as pd

# %%
with open(r'C:\Users\ASUS\OneDrive\Desktop\code\serious_projects\Fraud_Detection_System\data\output.jsonl', 'r') as file:
    data = file.readlines()

# %%
dat = [i.strip("\n") for i in data]

# %%
records = [json.loads(item) for item in dat]

# %%
df = pd.DataFrame(records)

# %%
df[:5]
# Out:
#                          transaction_id  user_id  merchant_id   amount  \
# 0  a100afa7-e13c-4b9d-b25d-80499e16c38e      267           21  2560.23
# 1           2025-11-20T12:27:28.127200Z      267           21  3198.95
# 2           2025-11-20T12:27:16.127200Z      267           21  3493.70
# 3           2025-11-20T12:27:34.127200Z      267           21  1733.41
# 4  c43c599b-018a-4cfe-80a5-c7f01ca7dad6      282           18    15.56
#
#                      timestamp            geo_location             device_id  \
# 0  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]     android_13_pixel7
# 1  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]     android_13_pixel7
# 2  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]     android_13_pixel7
# 3  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]     android_13_pixel7
# 4  2025-11-20T08:17:46.312417Z  [12.887258, 77.476368]  linux_ubuntu_firefox
#
#   merchant_category    city  fraud_score fraud_reasons  is_fraud  \
# ...

# %%
df.to_csv(r'C:\Users\ASUS\OneDrive\Desktop\code\serious_projects\Fraud_Detection_System\data\model_data.csv')
