# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul0Krishna/serious_projects/blob/main/model_crationandsaving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! unzip /content/model_data.zip
# Out:
# Archive:  /content/model_data.zip
#   inflating: model_data.csv

# %%
import pandas as pd
df = pd.read_csv('/content/model_data.csv')
df[:5]
# Out:
#    Unnamed: 0                        transaction_id  user_id  merchant_id  \
# 0           0  a100afa7-e13c-4b9d-b25d-80499e16c38e      267           21
# 1           1           2025-11-20T12:27:28.127200Z      267           21
# 2           2           2025-11-20T12:27:16.127200Z      267           21
# 3           3           2025-11-20T12:27:34.127200Z      267           21
# 4           4  c43c599b-018a-4cfe-80a5-c7f01ca7dad6      282           18
#
#     amount                    timestamp            geo_location  \
# 0  2560.23  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]
# 1  3198.95  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]
# 2  3493.70  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]
# 3  1733.41  2025-11-20T12:27:08.127200Z   [17.293838, 78.43787]
# 4    15.56  2025-11-20T08:17:46.312417Z  [12.887258, 77.476368]
#
#               device_id merchant_category    city  fraud_score  \
# 0     android_13_pixel7         utilities   Sūrat            2
# ...

# %%
y = df['is_fraud']

# %%
x = df[['amount','distance_from_home_km']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(n_estimators=1000, learning_rate=0.001).fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[  1,  30],
#        [  0, 164]])

# %%
acc =accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8461538461538461

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
